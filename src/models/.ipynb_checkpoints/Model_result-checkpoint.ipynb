# %%
import sys
import os
sys.path.append(os.path.abspath('../utils'))

# %%
import numpy as np
import pandas as pd
import preprocessing as pp
import tensorflow as tf
import preprocessing as pp
import matplotlib.pyplot as plt
import confusion_matrix as cmat
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
np.random.seed(13)
tf.random.set_seed(13)

# %%
X, y, X_columns, y_columns = pp.load_data(suffix='_result_no_measures')

# %%
# X, y, X_columns, y_columns = pp.preprocess(return_arrays=True, save_as_file=True, y_goal_diff=False, suffix='_result_no_measures')

# %%
print(X.shape)
print(y.shape)

print(list(X_columns.keys()))
print(list(y_columns.keys()))
# Out:
# (11244, 366, 11)
# (11244, 3)
# ['game_id', 'event_blocked_shot', 'event_faceoff', 'event_giveaway', 'event_hit', 'event_missed_shot', 'event_penalty', 'event_shot', 'event_takeaway', 'event_dummy', 'home_team_for']
# ['a_home_win', 'b_tie', 'c_away_win']

# %%
X_train, X_test, y_train, y_test, id_train, id_test = train_test_split(X[:,:,1:], y, X[:, 0, 0], test_size=0.25, random_state=13)

# %%
np.save("data/numpy/id_train", id_train)
np.save("data/numpy/id_test", id_test)

# %%
data_shape = tuple(X_train.shape[1:])
print(data_shape)
# Out:
# (366, 10)

# %%
print(np.sum(y_train, axis=0))
print(np.sum(y_test, axis=0))
# Out:
# [3618 1978 2837]
# [1168  678  965]

# %%
model_mlp = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=data_shape),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(y_train.shape[1], activation='softmax')
])

# %%
model_mlp.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model_mlp.fit(X_train, y_train, epochs=10, validation_split=0.2)
model_mlp.evaluate(X_test, y_test, verbose=0)
# Out:
# Train on 6746 samples, validate on 1687 samples
# Epoch 1/10
# 6746/6746 [==============================] - 3s 437us/sample - loss: 1.0802 - accuracy: 0.4165 - val_loss: 1.0439 - val_accuracy: 0.5098
# Epoch 2/10
# 6746/6746 [==============================] - 2s 331us/sample - loss: 1.0010 - accuracy: 0.5219 - val_loss: 0.9795 - val_accuracy: 0.5525
# Epoch 3/10
# 6746/6746 [==============================] - 3s 431us/sample - loss: 0.9312 - accuracy: 0.5719 - val_loss: 0.9548 - val_accuracy: 0.5673
# Epoch 4/10
# 6746/6746 [==============================] - 4s 543us/sample - loss: 0.8608 - accuracy: 0.6109 - val_loss: 0.9485 - val_accuracy: 0.5608
# Epoch 5/10
# 6746/6746 [==============================] - 4s 525us/sample - loss: 0.8347 - accuracy: 0.6257 - val_loss: 0.9345 - val_accuracy: 0.5797
# Epoch 6/10
# 6746/6746 [==============================] - 4s 598us/sample - loss: 0.8103 - accuracy: 0.6390 - val_loss: 0.9448 - val_accuracy: 0.5602
# Epoch 7/10
# 6746/6746 [==============================] - 3s 374us/sample - loss: 0.7835 - accuracy: 0.6518 - val_loss: 0.9487 - val_accuracy: 0.5643
# Epoch 8/10
# 6746/6746 [==============================] - 2s 336us/sample - loss: 0.7764 - accuracy: 0.6599 - val_loss: 0.9405 - val_accuracy: 0.5649
# Epoch 9/10
# 6746/6746 [==============================] - 3s 469us/sample - loss: 0.7555 - accuracy: 0.6736 - val_loss: 0.9577 - val_accuracy: 0.5637
# Epoch 10/10
# 6746/6746 [==============================] - 2s 327us/sample - loss: 0.7545 - accuracy: 0.6671 - val_loss: 0.9431 - val_accuracy: 0.5691
# [0.9598916533874557, 0.5827108]

# %%
y_pred_mlp = model_mlp.predict(X_test)

# %%
model_mlp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 366, 16)           176
# _________________________________________________________________
# dense_1 (Dense)              (None, 366, 16)           272
# _________________________________________________________________
# flatten (Flatten)            (None, 5856)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 5856)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 17571
# =================================================================
# Total params: 18,019
# Trainable params: 18,019
# Non-trainable params: 0
# _________________________________________________________________

# %%
classes = ['home win', 'tie (OT/SO)', 'away win']

# %%
for i in range(y_pred_mlp.shape[1]):
    print("Predicted result " + classes[i] + ":\t", np.sum(y_pred_mlp.argmax(axis=1) == i))
# Out:
# Predicted result home win:	 1593
# Predicted result tie (OT/SO):	 267
# Predicted result away win:	 951

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

cmat.plot(y_test, y_pred_mlp, classes=classes, normalize=True, show_colorbar=False, ax=ax[0])
cmat.plot(y_test, y_pred_mlp, classes=classes, normalize=False, show_colorbar=False, ax=ax[1])

plt.show()

# %%
print(classification_report(y_test.argmax(axis=1), y_pred_mlp.argmax(axis=1), target_names=classes))
# Out:
# precision    recall  f1-score   support
#
#     home win       0.60      0.81      0.69      1168
#  tie (OT/SO)       0.33      0.13      0.19       678
#     away win       0.63      0.62      0.63       965
#
#     accuracy                           0.58      2811
#    macro avg       0.52      0.52      0.50      2811
# weighted avg       0.54      0.58      0.55      2811

# %%
model_conv1d = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(64, 12, activation='relu', input_shape=data_shape),
    tf.keras.layers.Conv1D(32, 8, activation='relu'),
    tf.keras.layers.AveragePooling1D(3),
    tf.keras.layers.Conv1D(16, 6, activation='relu'),
    tf.keras.layers.Conv1D(16, 6, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(y_train.shape[1], activation='softmax')
])

# %%
model_conv1d.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model_conv1d.fit(X_train, y_train, epochs=10, validation_split=0.2)
model_conv1d.evaluate(X_test, y_test, verbose=2)
# Out:
# Train on 6746 samples, validate on 1687 samples
# Epoch 1/10
# 6746/6746 [==============================] - 10s 2ms/sample - loss: 1.0796 - accuracy: 0.4186 - val_loss: 1.0692 - val_accuracy: 0.4309
# Epoch 2/10
# 6746/6746 [==============================] - 10s 1ms/sample - loss: 1.0737 - accuracy: 0.4286 - val_loss: 1.0687 - val_accuracy: 0.4309
# Epoch 3/10
# 6746/6746 [==============================] - 10s 1ms/sample - loss: 1.0684 - accuracy: 0.4286 - val_loss: 1.0588 - val_accuracy: 0.4309
# Epoch 4/10
# 6746/6746 [==============================] - 10s 1ms/sample - loss: 1.0550 - accuracy: 0.4286 - val_loss: 1.0434 - val_accuracy: 0.4309
# Epoch 5/10
# 6746/6746 [==============================] - 10s 1ms/sample - loss: 1.0302 - accuracy: 0.4339 - val_loss: 1.0142 - val_accuracy: 0.5679
# Epoch 6/10
# 6746/6746 [==============================] - 9s 1ms/sample - loss: 0.9817 - accuracy: 0.5566 - val_loss: 0.9324 - val_accuracy: 0.6094
# Epoch 7/10
# 6746/6746 [==============================] - 8s 1ms/sample - loss: 0.9370 - accuracy: 0.5934 - val_loss: 0.8949 - val_accuracy: 0.6260
# Epoch 8/10
# 6746/6746 [==============================] - 8s 1ms/sample - loss: 0.9011 - accuracy: 0.6060 - val_loss: 0.9050 - val_accuracy: 0.6206
# Epoch 9/10
# 6746/6746 [==============================] - 8s 1ms/sample - loss: 0.8829 - accuracy: 0.6124 - val_loss: 0.8593 - val_accuracy: 0.6271
# Epoch 10/10
# 6746/6746 [==============================] - 9s 1ms/sample - loss: 0.8415 - accuracy: 0.6324 - val_loss: 0.8584 - val_accuracy: 0.6277
# 2811/1 - 1s - loss: 0.8581 - accuracy: 0.6094
# [0.8836282526246596, 0.6093917]

# %%
y_pred_conv1d = model_conv1d.predict(X_test)

# %%
model_conv1d.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 355, 64)           7744
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 348, 32)           16416
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 116, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 111, 16)           3088
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 106, 16)           1552
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 28,851
# Trainable params: 28,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
for i in range(y_pred_mlp.shape[1]):
    print("Predicted result " + classes[i] + ":\t", np.sum(y_pred_conv1d.argmax(axis=1) == i))
# Out:
# Predicted result home win:	 1626
# Predicted result tie (OT/SO):	 0
# Predicted result away win:	 1185

# %%
cmat.plot(y_test, y_pred_conv1d, classes=classes, normalize=True)
cmat.plot(y_test, y_pred_conv1d, classes=classes, normalize=False)

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

cmat.plot(y_test, y_pred_mlp, classes=classes, normalize=False, title="Feedforward",
            show_colorbar=False, ax=ax[0])
cmat.plot(y_test, y_pred_conv1d, classes=classes, normalize=False, title="1D Convolution",                          show_colorbar=False, ax=ax[1])

plt.savefig('confusion_matrix.png')

# %%
fig, ax = plt.subplots(figsize=(5,5))

cmat.plot(y_test, y_pred_mlp, classes=classes, normalize=False, title="Feedforward",
            show_colorbar=False, ax=ax)

fig.tight_layout()
fig.savefig('img/confusion_matrix_mlp.png')

# %%
fig, ax = plt.subplots(figsize=(5,5))

cmat.plot(y_test, y_pred_conv1d, classes=classes, normalize=False, title="1D Convolution",
            show_colorbar=False, ax=ax)

fig.tight_layout()
fig.savefig('img/confusion_matrix_conv1d.png')

# %%
print(classification_report(y_test.argmax(axis=1), y_pred_conv1d.argmax(axis=1), target_names=classes))
# Out:
# precision    recall  f1-score   support
#
#     home win       0.60      0.88      0.71      1168
#  tie (OT/SO)       1.00      0.00      0.00       678
#     away win       0.62      0.72      0.66       965
#
#     accuracy                           0.61      2811
#    macro avg       0.74      0.53      0.46      2811
# weighted avg       0.70      0.61      0.53      2811

# %%
x = np.arange(len(classes)) 
width = 0.2

plt.bar(x - width, np.mean(y_pred_mlp, axis=0), width, label='MLP')
plt.bar(x, np.mean(y_pred_conv1d, axis=0), width, label='Conv1D')
plt.bar(x + width, np.mean(y_test, axis=0), width, label='True proportion')

plt.legend(loc='upper right')
plt.xticks(x, classes)
plt.title("Average confidence in prediction")

plt.show()

# %%
mlp_prop = np.zeros(y.shape[1])
conv1d_prop = np.zeros(y.shape[1])

for i in range(y.shape[1]):
    mlp_prop[i] = np.sum(y_pred_mlp.argmax(axis=1) == i) / len(y_test)
    conv1d_prop[i] = np.sum(y_pred_conv1d.argmax(axis=1) == i) / len(y_test)

# %%
x = np.arange(len(classes)) 
width = 0.2

plt.bar(x - width, mlp_prop, width, label='MLP')
plt.bar(x, conv1d_prop, width, label='Conv1D')
plt.bar(x + width, np.mean(y_test, axis=0), width, label='True')

plt.title("Predicted classes proportionally")
plt.legend(loc='upper left')
plt.xticks(x, classes)

plt.show()

# %%
confidence_true_mlp = (y_pred_mlp * y_test).max(axis=1)
confidence_true_conv1d = (y_pred_conv1d * y_test).max(axis=1)

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,8))

ax[0].hist(confidence_true_mlp, bins=30)
ax[1].hist(confidence_true_conv1d, bins=30)

ax[0].set_title("MLP")
ax[1].set_title("Conv1D")


plt.xlim((0,1))
plt.ylim((0, 400))
plt.suptitle("Confidence to true class")

plt.show()

# %%
extreme_results_mlp = id_test[np.argsort(confidence_true_mlp)[:10]]
extreme_results_conv1d = id_test[np.argsort(confidence_true_conv1d)[:10]]

# %%
game_stats = pd.read_csv("data/csv/game_teams_stats.csv")

# %%
home = game_stats.loc[game_stats['HoA']=='home']
away = game_stats.loc[game_stats['HoA']=='away']
games = home.merge(away, on='game_id', suffixes=['_home', '_away'])

# %%
games.columns

# %%
relevant_columns = ['team_id_home', 'goals_home', 'shots_home', 'hits_home', 'pim_home',
       'powerPlayOpportunities_home', 'faceOffWinPercentage_home', 'giveaways_home', 'takeaways_home', 'team_id_away', 'goals_away', 'shots_away', 'hits_away', 'pim_away',
       'powerPlayOpportunities_away', 'giveaways_away', 'takeaways_away']

# %%
games.loc[games['game_id'].isin(extreme_results_mlp), relevant_columns]

# %%
games.loc[games['game_id'].isin(extreme_results_conv1d), relevant_columns]

# %%
games['pdo_home'] = games['goals_home'] / games['shots_home'] + (games['shots_away']-games['goals_away']) / games['shots_away']

games['pdo_away'] = games['goals_away'] / games['shots_away'] + (games['shots_home']-games['goals_home']) / games['shots_home']

# %%
goal_diff_mlp = y_test.argmax(axis=1) - y_pred_mlp.argmax(axis=1)
goal_diff_conv1d = y_test.argmax(axis=1) - y_pred_conv1d.argmax(axis=1)

# %%
games = games.sort_values(by='game_id')

# %%
games_test = games[games['game_id'].isin(np.sort(id_test))]

# %%
games_test.head()

# %%
games_test['game_id'].all() == np.sort(id_test).all()

# %%
sns.set()

fig, ax = plt.subplots(1, 2, figsize=(16,8))

sns.scatterplot(games_test['pdo_home'], goal_diff_mlp[np.argsort(id_test)], ax=ax[0])
sns.scatterplot(games_test['pdo_home'], goal_diff_conv1d[np.argsort(id_test)], ax=ax[1])

ax[0].set_title("MLP", fontsize=16)
ax[1].set_title("Conv1D", fontsize=16)

ax[0].set_ylabel("True(GD)-E(GD)")
ax[1].set_ylabel("True(GD)-E(GD)")

plt.show()

# %%
print(np.corrcoef(games_test['pdo_home'], goal_diff_mlp[np.argsort(id_test)])[0, 1])

# %%
print(np.corrcoef(games_test['pdo_home'], goal_diff_conv1d[np.argsort(id_test)])[0, 1])
